# %% [markdown]
# 0624

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import time
import re
import pandas as pd
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# # 사이트 링크
# https://www.tashu.or.kr/userStationAction.do?process=list

# %%
# 크롤링 정보를 저장할 데이터프레임 선언
# 지도로 확인할 거라 위도와 경도를 담을 컬럼아 필요
data = pd.DataFrame(columns=['스테이션명',	'위치',	'상태정보',	'위도', '경도'])


# 크롤링 할 타슈 사이트 주소
url_tashu= 'https://www.tashu.or.kr/userStationAction.do?process=list'

# 페이지 이동시 추가로 적어줘야 되는 url
url_add='&page='

# 전체 페이지 수
total_page = 27

# 27 page에 대한 정보를 추출하는 for문
for index in range(1, total_page+1) : #+1 안하면 26페이지까지만 수집되기 때문
  if index == 1:
    url = url_tashu # 첫번째 페이지
  else:
    url = url_tashu + url_add + str(index) # 페이지 정보 추가

  # url에서 HTML 추출
  html = urlopen(url)

  # HTML을 parsing하여 변환
  bsObject = BeautifulSoup(html, 'html.parser', from_encoding='utf-8') #html을 html.parser로 사용하라

  # history_table이라고 하는 class를 가진 table만 추출
  table = bsObject.find_all('table', {'class', 'history_table'})

# table 내에서 tr 추출
  tr= table[0].find_all('tr')

  # 첫 tr contents가 아니라, 데이터 정보를 의미하기 떄문에 제외
  tr = tr[1:len(tr)]

  # 한페이지의 정보를 크롤링
  for index_tr in range(0, len(tr)):
    td = tr[index_tr].find_all('td')

    # 장소
    station = td[0].text.split('.')[1] # 1. 무역전시관입구(택시승강장)

    # 위치
    location = td[1].text

    # 상태
    condition = td[2].text

    # 좌표추출
    geo =td[3].a.attrs['href'].split('(')[1] # '36.374389' , '127.392375');" 추출

    # 위도, 경도 추출을 위한 데이터 클렌징
    geo = re.sub('[;)]','', geo) #'36.374389' , '127.392375');" -> '36.374389' ,'127.392375'
    detail_location = geo.replace("'", "") # 작은 따옴표 삭제

    # 위도 Latitude
    lat = detail_location.split(',')[0]

    # 경도 Longitude
    lon = detail_location.split(',')[1]

    # data에 크롤링 결과 저장
    data = data.append({'스테이션명' : station,
                        '위치' : location,
                        '상태정보': condition,
                        '위도' : lat,
                        '경도': lon},
                        ignore_index=True)

    print('Complete of' + str(index_tr+1) + ' indormation with ' 
          + str(index) + ' Page')
    
  # Crawling 막히는 것 방지
  time.sleep(1)

print('-------------------------------------------------------')
print(data)


# 크롤링 데이터 저장하기

data.to_csv('TASHU.csv')
# Out:
# Complete of1 indormation with 1 Page
# Complete of2 indormation with 1 Page
# Complete of3 indormation with 1 Page
# Complete of4 indormation with 1 Page
# Complete of5 indormation with 1 Page
# Complete of6 indormation with 1 Page
# Complete of7 indormation with 1 Page
# Complete of8 indormation with 1 Page
# Complete of9 indormation with 1 Page
# Complete of10 indormation with 1 Page
# Complete of1 indormation with 2 Page
# Complete of2 indormation with 2 Page
# Complete of3 indormation with 2 Page
# Complete of4 indormation with 2 Page
# Complete of5 indormation with 2 Page
# Complete of6 indormation with 2 Page
# Complete of7 indormation with 2 Page
# Complete of8 indormation with 2 Page
# Complete of9 indormation with 2 Page
# Complete of10 indormation with 2 Page
# Complete of1 indormation with 3 Page
# Complete of2 indormation with 3 Page
# Complete of3 indormation with 3 Page
# Complete of4 indormation with 3 Page
# Complete of5 indormation with 3 Page
# Complete of6 indormation with 3 Page
# Complete of7 indormation with 3 Page
# Complete of8 indormation with 3 Page
# Complete of9 indormation with 3 Page
# Complete of10 indormation with 3 Page
# Complete of1 indormation with 4 Page
# Complete of2 indormation with 4 Page
# Complete of3 indormation with 4 Page
# Complete of4 indormation with 4 Page
# Complete of5 indormation with 4 Page
# Complete of6 indormation with 4 Page
# Complete of7 indormation with 4 Page
# Complete of8 indormation with 4 Page
# Complete of9 indormation with 4 Page
# Complete of10 indormation with 4 Page
# Complete of1 indormation with 5 Page
# Complete of2 indormation with 5 Page
# Complete of3 indormation with 5 Page
# Complete of4 indormation with 5 Page
# Complete of5 indormation with 5 Page
# Complete of6 indormation with 5 Page
# Complete of7 indormation with 5 Page
# Complete of8 indormation with 5 Page
# Complete of9 indormation with 5 Page
# Complete of10 indormation with 5 Page
# Complete of1 indormation with 6 Page
# Complete of2 indormation with 6 Page
# Complete of3 indormation with 6 Page
# Complete of4 indormation with 6 Page
# Complete of5 indormation with 6 Page
# Complete of6 indormation with 6 Page
# Complete of7 indormation with 6 Page
# Complete of8 indormation with 6 Page
# Complete of9 indormation with 6 Page
# Complete of10 indormation with 6 Page
# Complete of1 indormation with 7 Page
# Complete of2 indormation with 7 Page
# Complete of3 indormation with 7 Page
# Complete of4 indormation with 7 Page
# Complete of5 indormation with 7 Page
# Complete of6 indormation with 7 Page
# Complete of7 indormation with 7 Page
# Complete of8 indormation with 7 Page
# Complete of9 indormation with 7 Page
# Complete of10 indormation with 7 Page
# Complete of1 indormation with 8 Page
# Complete of2 indormation with 8 Page
# Complete of3 indormation with 8 Page
# Complete of4 indormation with 8 Page
# Complete of5 indormation with 8 Page
# Complete of6 indormation with 8 Page
# Complete of7 indormation with 8 Page
# Complete of8 indormation with 8 Page
# Complete of9 indormation with 8 Page
# Complete of10 indormation with 8 Page
# Complete of1 indormation with 9 Page
# Complete of2 indormation with 9 Page
# Complete of3 indormation with 9 Page
# Complete of4 indormation with 9 Page
# Complete of5 indormation with 9 Page
# Complete of6 indormation with 9 Page
# Complete of7 indormation with 9 Page
# Complete of8 indormation with 9 Page
# Complete of9 indormation with 9 Page
# Complete of10 indormation with 9 Page
# Complete of1 indormation with 10 Page
# Complete of2 indormation with 10 Page
# Complete of3 indormation with 10 Page
# Complete of4 indormation with 10 Page
# Complete of5 indormation with 10 Page
# Complete of6 indormation with 10 Page
# Complete of7 indormation with 10 Page
# Complete of8 indormation with 10 Page
# Complete of9 indormation with 10 Page
# Complete of10 indormation with 10 Page
# Complete of1 indormation with 11 Page
# Complete of2 indormation with 11 Page
# Complete of3 indormation with 11 Page
# Complete of4 indormation with 11 Page
# Complete of5 indormation with 11 Page
# Complete of6 indormation with 11 Page
# Complete of7 indormation with 11 Page
# Complete of8 indormation with 11 Page
# Complete of9 indormation with 11 Page
# Complete of10 indormation with 11 Page
# Complete of1 indormation with 12 Page
# Complete of2 indormation with 12 Page
# Complete of3 indormation with 12 Page
# Complete of4 indormation with 12 Page
# Complete of5 indormation with 12 Page
# Complete of6 indormation with 12 Page
# Complete of7 indormation with 12 Page
# Complete of8 indormation with 12 Page
# Complete of9 indormation with 12 Page
# Complete of10 indormation with 12 Page
# Complete of1 indormation with 13 Page
# Complete of2 indormation with 13 Page
# Complete of3 indormation with 13 Page
# Complete of4 indormation with 13 Page
# Complete of5 indormation with 13 Page
# Complete of6 indormation with 13 Page
# Complete of7 indormation with 13 Page
# Complete of8 indormation with 13 Page
# Complete of9 indormation with 13 Page
# Complete of10 indormation with 13 Page
# Complete of1 indormation with 14 Page
# Complete of2 indormation with 14 Page
# Complete of3 indormation with 14 Page
# Complete of4 indormation with 14 Page
# Complete of5 indormation with 14 Page
# Complete of6 indormation with 14 Page
# Complete of7 indormation with 14 Page
# Complete of8 indormation with 14 Page
# Complete of9 indormation with 14 Page
# Complete of10 indormation with 14 Page
# Complete of1 indormation with 15 Page
# Complete of2 indormation with 15 Page
# Complete of3 indormation with 15 Page
# Complete of4 indormation with 15 Page
# Complete of5 indormation with 15 Page
# Complete of6 indormation with 15 Page
# Complete of7 indormation with 15 Page
# Complete of8 indormation with 15 Page
# Complete of9 indormation with 15 Page
# Complete of10 indormation with 15 Page
# Complete of1 indormation with 16 Page
# Complete of2 indormation with 16 Page
# Complete of3 indormation with 16 Page
# Complete of4 indormation with 16 Page
# Complete of5 indormation with 16 Page
# Complete of6 indormation with 16 Page
# Complete of7 indormation with 16 Page
# Complete of8 indormation with 16 Page
# Complete of9 indormation with 16 Page
# Complete of10 indormation with 16 Page
# Complete of1 indormation with 17 Page
# Complete of2 indormation with 17 Page
# Complete of3 indormation with 17 Page
# Complete of4 indormation with 17 Page
# Complete of5 indormation with 17 Page
# Complete of6 indormation with 17 Page
# Complete of7 indormation with 17 Page
# Complete of8 indormation with 17 Page
# Complete of9 indormation with 17 Page
# Complete of10 indormation with 17 Page
# Complete of1 indormation with 18 Page
# Complete of2 indormation with 18 Page
# Complete of3 indormation with 18 Page
# Complete of4 indormation with 18 Page
# Complete of5 indormation with 18 Page
# Complete of6 indormation with 18 Page
# Complete of7 indormation with 18 Page
# Complete of8 indormation with 18 Page
# Complete of9 indormation with 18 Page
# Complete of10 indormation with 18 Page
# Complete of1 indormation with 19 Page
# Complete of2 indormation with 19 Page
# Complete of3 indormation with 19 Page
# Complete of4 indormation with 19 Page
# Complete of5 indormation with 19 Page
# Complete of6 indormation with 19 Page
# Complete of7 indormation with 19 Page
# Complete of8 indormation with 19 Page
# Complete of9 indormation with 19 Page
# Complete of10 indormation with 19 Page
# Complete of1 indormation with 20 Page
# Complete of2 indormation with 20 Page
# Complete of3 indormation with 20 Page
# Complete of4 indormation with 20 Page
# Complete of5 indormation with 20 Page
# Complete of6 indormation with 20 Page
# Complete of7 indormation with 20 Page
# Complete of8 indormation with 20 Page
# Complete of9 indormation with 20 Page
# Complete of10 indormation with 20 Page
# Complete of1 indormation with 21 Page
# Complete of2 indormation with 21 Page
# Complete of3 indormation with 21 Page
# Complete of4 indormation with 21 Page
# Complete of5 indormation with 21 Page
# Complete of6 indormation with 21 Page
# Complete of7 indormation with 21 Page
# Complete of8 indormation with 21 Page
# Complete of9 indormation with 21 Page
# Complete of10 indormation with 21 Page
# Complete of1 indormation with 22 Page
# Complete of2 indormation with 22 Page
# Complete of3 indormation with 22 Page
# Complete of4 indormation with 22 Page
# Complete of5 indormation with 22 Page
# Complete of6 indormation with 22 Page
# Complete of7 indormation with 22 Page
# Complete of8 indormation with 22 Page
# Complete of9 indormation with 22 Page
# Complete of10 indormation with 22 Page
# Complete of1 indormation with 23 Page
# Complete of2 indormation with 23 Page
# Complete of3 indormation with 23 Page
# Complete of4 indormation with 23 Page
# Complete of5 indormation with 23 Page
# Complete of6 indormation with 23 Page
# Complete of7 indormation with 23 Page
# Complete of8 indormation with 23 Page
# Complete of9 indormation with 23 Page
# Complete of10 indormation with 23 Page
# Complete of1 indormation with 24 Page
# Complete of2 indormation with 24 Page
# Complete of3 indormation with 24 Page
# Complete of4 indormation with 24 Page
# Complete of5 indormation with 24 Page
# Complete of6 indormation with 24 Page
# Complete of7 indormation with 24 Page
# Complete of8 indormation with 24 Page
# Complete of9 indormation with 24 Page
# Complete of10 indormation with 24 Page
# Complete of1 indormation with 25 Page
# Complete of2 indormation with 25 Page
# Complete of3 indormation with 25 Page
# Complete of4 indormation with 25 Page
# Complete of5 indormation with 25 Page
# Complete of6 indormation with 25 Page
# Complete of7 indormation with 25 Page
# Complete of8 indormation with 25 Page
# Complete of9 indormation with 25 Page
# Complete of10 indormation with 25 Page
# Complete of1 indormation with 26 Page
# Complete of2 indormation with 26 Page
# Complete of3 indormation with 26 Page
# Complete of4 indormation with 26 Page
# Complete of5 indormation with 26 Page
# Complete of6 indormation with 26 Page
# Complete of7 indormation with 26 Page
# Complete of8 indormation with 26 Page
# Complete of9 indormation with 26 Page
# Complete of10 indormation with 26 Page
# Complete of1 indormation with 27 Page
# Complete of2 indormation with 27 Page
# -------------------------------------------------------
#                  스테이션명                 위치 상태정보         위도           경도
# 0       무역전시관입구(택시승강장)       유성구 도룡동 3-8    정상  36.374580   127.386131
# 1              대전컨벤션센터      유성구 도룡동 4-19    정상  36.374389   127.392375
# 2               한밭수목원1        서구 만년동 396    정상  36.368995   127.388451
# 3    초원아파트(104동 버스정류장)        서구 만년동 401    정상  36.367945   127.379302
# 4      둔산대공원 입구(버스정류장)   서구 둔산2동 1521-10    정상  36.364974   127.388856
# ..                 ...                ...  ...        ...          ...
# 257              천문대입구       유성구 신성동 458    정상  36.382848   127.355004
# 258              대덕대학교         유성구 장동 48    정상  36.390462   127.362420
# 259        오정농수산물 도매시장      대덕구 오정동 45-1    정상  36.357693   127.407763
# 260   도로교통공단(건너편 라도무스)      유성구 원신흥동 608    정상  36.332692   127.333128
# 261              반석 더샵       유성구 반석동 704    정상  36.390096   127.305095
#
# [262 rows x 5 columns]
